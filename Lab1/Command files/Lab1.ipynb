# %% [markdown]
# Import

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import shutil

# %%
#read csv files
drink=pd.read_csv("drinks.csv")

# %%
#create "Original Data" file
print(os.getcwd())
dirName = 'Original Data'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " Created ") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# C:\Users\Lenovo\Downloads\aibd_labs_2020\Lab1
# Directory  Original Data  Created

# %%
#create "Documents" file
dirName = 'Documents'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " Created ") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  Documents  Created

# %%
#create "Analysis Data" file
dirName = 'Analysis Data'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " Created ") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  Analysis Data  Created

# %%
#create "Command files" file
dirName = 'Command files'
try:
    # Create target Directory
    os.mkdir(dirName)
    print("Directory " , dirName ,  " Created ") 
except FileExistsError:
    print("Directory " , dirName ,  " already exists")
# Out:
# Directory  Command files  Created

# %%
#removing last column
drink=drink.drop(columns=['total_litres_of_pure_alcohol'])

# %%
# Source path 
source = 'drinks.csv'
  
# Destination path 
destination ='Original Data'
  
# Move the content of 
# source to destination 
dest = shutil.move(source, destination)

# %%
#set index as country
drink=drink.set_index('country')

# %%
drink
# Out:
#              beer_servings  spirit_servings  wine_servings
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
# [193 rows x 3 columns]

# %%
drink.plot.bar(figsize=(50,50))

# %%
# Bar charts from splited dataframe by servings
drink['beer_servings'].plot.bar(figsize=(50,10))

# %%
drink['wine_servings'].plot.bar(figsize=(50,10))

# %%
drink['spirit_servings'].plot.bar(figsize=(50,10))

# %%
#Poland pie plot of alcohol servings
drink.loc['Poland'].plot.pie()

# %%
drink.to_csv('drink_2.csv')

# %%
# Source path 
source = 'drink_2.csv'
  
# Destination path 
destination ='Analysis Data'
  
# Move the content of 
# source to destination 
dest = shutil.move(source, destination)

# %%
# Source path 
source = 'drink_2.csv'
  
# Destination path 
destination ='Analysis Data'
  
# Move the content of 
# source to destination 
dest = shutil.move(source, destination)
